# %%
import record_reader as rr
# import importlib
# importlib.reload(rr)

# %%
jason_path = "./experiment_records/experiment_004_20260413-182427_records.json"

# %%
experiment_id, notes, df = rr.parse_experiment_records(jason_path)
print(f"Experiment ID: {experiment_id}")
print(f"Notes: {notes}")
# sort the dataframe by final_test_eer in ascending order
df = df.sort_values(by="final_test_eer", ascending=True)
df
# Out:
# Experiment ID: experiment_004_20260413-182427
# Notes: testing colorspaces layers (rgp and hsv) with resnet block with multiple data filtering and full data
#       input_size pixel_range              model       lr  epochs  \
# 3  [224, 224, 3]  [0.0, 1.0]  MC-ResNet-RGB-HSV  0.00005      50
# 2  [224, 224, 3]  [0.0, 1.0]  MC-ResNet-RGB-HSV  0.00005      49
# 1  [224, 224, 3]  [0.0, 1.0]  MC-ResNet-RGB-HSV  0.00005      26
# 0  [224, 224, 3]  [0.0, 1.0]  MC-ResNet-RGB-HSV  0.00005      22
#
#    final_test_loss  final_test_acc  final_test_eer  \
# 3         0.040173        0.986499        0.013405
# 2         0.047295        0.988270        0.018620
# 1         0.045653        0.980940        0.022798
# 0         0.119571        0.947332        0.048189
#
#                                    data_augmentation  filtering_ratio   \
# 3  {'rotation_range': 0.15, 'horizontal_flip': 1,...               1.0
# 2  {'rotation_range': 0.15, 'horizontal_flip': 1,...               0.5
# ...

# %%
rr.plot_training_trends(jason_path, record_index=3)
