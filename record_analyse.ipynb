# %%
import record_reader as rr
import importlib
importlib.reload(rr)
# Out:
# <module 'record_reader' from 'c:\\Users\\ThinkPad\\Documents\\UNIVERSITY\\PFE2\\record_reader.py'>

# %%
jason_path = "./experiment_records/experiment_037_20260427-020056_records.json"

# %%
experiment_id, notes, df = rr.parse_experiment_records(jason_path)
print(f"Experiment ID: {experiment_id}")
print(f"Notes: {notes}")
# sort the dataframe by final_test_eer in ascending order
df = df.sort_values(by="final_test_eer", ascending=True)
df
# Out:
# Experiment ID: experiment_037_20260427-020056
# Notes:  get mid features with hybrid pooling only rgb
#       input_size pixel_range                   model      lr  epochs  \
# 0  [224, 224, 3]      [0, 1]  resNet50V2_FASD_RGB_V4  0.0001      40
#
#    final_test_loss  final_test_acc  final_test_eer  \
# 0         0.085689        0.988035        0.015578
#
#                                    data_augmentation  filtering_ratio   \
# 0  {'rotation_range': 0.15, 'horizontal_flip': 1,...               0.5
#
#   filtering_method                               filtering_parameters
# 0  uniform_sampling  ({'data_map_path': 'data_maps/CASIA_FASD_V3_50...

# %%
rr.plot_training_trends_2(jason_path, record_index=0)
