# %%
import record_reader as rr
import importlib
importlib.reload(rr)
# Out:
# <module 'record_reader' from 'c:\\Users\\ThinkPad\\Documents\\UNIVERSITY\\PFE2\\record_reader.py'>

# %%
jason_path = "./experiment_records/experiment_001_20260412-184353_records.json"

# %%
experiment_id, notes, df = rr.parse_experiment_records(jason_path)
print(f"Experiment ID: {experiment_id}")
print(f"Notes: {notes}")
df
# Out:
# Experiment ID: experiment_001
# Notes: Testing the training pipeline with a simple configuration.
#       input_size pixel_range                       model      lr  epochs  \
# 0  [224, 224, 3]  [0.0, 1.0]  model_architecture_example  0.0001       6
# 1  [224, 224, 3]  [0.0, 1.0]  model_architecture_example  0.0001       6
#
#    final_test_loss  final_test_acc  final_test_eer  \
# 0         0.887464        0.244084        0.430325
# 1         0.637327        0.745330        0.334730
#
#                                    data_augmentation  \
# 0  {'rotation_range': 0.15, 'horizontal_flip': 0,...
# 1  {'rotation_range': 0.15, 'horizontal_flip': 0,...
#
#                                filtering_parameters
# 0  ({'data_map_path': 'data_maps/CASIA_FASD_v3_10...
# 1  ({'data_map_path': 'data_maps/CASIA_FASD_v3_al...

# %%
rr.plot_training_trends(jason_path, record_index=0)
