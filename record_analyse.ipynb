# %%
import record_reader as rr
import importlib
importlib.reload(rr)
# Out:
# <module 'record_reader' from 'c:\\Users\\ThinkPad\\Documents\\UNIVERSITY\\PFE2\\record_reader.py'>

# %%
jason_path = "./experiment_records/experiment_003_20260413-013917_records.json"

# %%
experiment_id, notes, df = rr.parse_experiment_records(jason_path)
print(f"Experiment ID: {experiment_id}")
print(f"Notes: {notes}")
# sort the dataframe by final_test_eer in ascending order
df = df.sort_values(by="final_test_eer", ascending=True)
df
# Out:
# Experiment ID: experiment_003
# Notes: testing colorspaces layers with resnet block
#       input_size pixel_range      model       lr  epochs  final_test_loss  \
# 3  [224, 224, 3]  [0.0, 1.0]  MC-ResNet  0.00005      24         0.089946
# 0  [224, 224, 3]  [0.0, 1.0]  MC-ResNet  0.00005      41         0.126563
# 1  [224, 224, 3]  [0.0, 1.0]  MC-ResNet  0.00005      26         0.092948
# 2  [224, 224, 3]  [0.0, 1.0]  MC-ResNet  0.00005      25         0.143124
# 4  [224, 224, 3]  [0.0, 1.0]  MC-ResNet  0.00005      24         0.104033
# 5  [224, 224, 3]  [0.0, 1.0]  MC-ResNet  0.00005      24         0.148577
#
#    final_test_acc  final_test_eer  \
# 3        0.974690        0.024887
# 0        0.970841        0.027518
# 1        0.971907        0.029835
# 2        0.968712        0.031083
# 4        0.961373        0.038278
# 5        0.959971        0.046079
#
#                                    data_augmentation  filtering_ratio   \
# 3  {'rotation_range': 0.15, 'horizontal_flip': 1,...               0.5
# 0  {'rotation_range': 0.15, 'horizontal_flip': 1,...               0.3
# 1  {'rotation_range': 0.15, 'horizontal_flip': 1,...               0.3
# 2  {'rotation_range': 0.15, 'horizontal_flip': 1,...               0.5
# 4  {'rotation_range': 0.15, 'horizontal_flip': 1,...               0.7
# 5  {'rotation_range': 0.15, 'horizontal_flip': 1,...               0.7
#
#                               filtering_method   \
# 3                              uniform_sampling
# 0  brightness_contrast_movement_based_selecting
# 1                              uniform_sampling
# 2  brightness_contrast_movement_based_selecting
# 4  brightness_contrast_movement_based_selecting
# 5                              uniform_sampling
#
#                                filtering_parameters
# 3  ({'data_map_path': '/kaggle/working/face-anti-...
# 0  ({'data_map_path': '/kaggle/working/face-anti-...
# 1  ({'data_map_path': '/kaggle/working/face-anti-...
# 2  ({'data_map_path': '/kaggle/working/face-anti-...
# 4  ({'data_map_path': '/kaggle/working/face-anti-...
# 5  ({'data_map_path': '/kaggle/working/face-anti-...

# %%
rr.plot_training_trends(jason_path, record_index=3)
