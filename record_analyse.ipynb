# %%
import record_reader as rr
import importlib
importlib.reload(rr)
rr.parse_experiment_records("./experiment_records/experiment_001_20260412-174427_records.json")
# Out:
#     experiment_id                       model      lr  epochs_completed  \
# 0  experiment_001  model_architecture_example  0.0001                 6
#
#    final_test_loss  final_test_acc  final_test_eer  \
# 0         0.531974        0.770534        0.285758
#
#                                    data_augmentation  \
# 0  {'rotation_range': 0.15, 'horizontal_flip': 0,...
#
#                                 filtering_parameters
# 0  {'keep_ratio': 0.8, 'data_map_path': 'data_map...

# %%
rr.plot_training_trends("./experiment_records/experiment_001_20260412-174427_records.json",record_index=0)
